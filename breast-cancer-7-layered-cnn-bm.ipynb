# %%
# importing all the required Libraries
from collections import Counter
import cv2
import os
import glob
import skimage
import numpy as np
import pandas as pd
import seaborn as sn
import preprocessing
from tqdm import tqdm
from PIL import Image
from os import listdir
import matplotlib.pyplot as plt
from skimage.transform import resize
from collections import Counter

sn.set()

from sklearn.svm import SVC # SVC
from sklearn import metrics
from sklearn.utils import shuffle
from xgboost import XGBClassifier # XGBClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import compute_class_weight
from sklearn.preprocessing import MinMaxScaler,LabelBinarizer
from sklearn.ensemble import AdaBoostClassifier # AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier # KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier # RandomForestClassifier
from sklearn.model_selection import train_test_split

import tensorflow 
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import AUC
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications.vgg16 import VGG16 # VGG16
from tensorflow.keras.applications.vgg19 import VGG19 # VGG19
from tensorflow.keras.applications.resnet50 import ResNet50 # ResNet50
from tensorflow.keras.applications.xception import Xception # Xception
from tensorflow.keras.applications.mobilenet import MobileNet # MobileNet
from tensorflow.keras.applications.nasnet import NASNetMobile # NASNetMobile
from tensorflow.keras.applications.densenet import DenseNet169 # DenseNet169
from tensorflow.keras.applications.densenet import DenseNet121 # DenseNet121
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2 # MobileNetV2
from tensorflow.keras.applications.inception_v3 import InceptionV3 # InceptionV3
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten, Activation, GlobalAveragePooling2D,Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
no_angles = 360
url ='/kaggle/input/mias-mammography/all-mias/'

# %%
def save_dictionary(path,data):
    print('saving catalog...')
    #open('u.item', encoding="utf-8")
    import json
    with open(path,'w') as outfile:
        json.dump(str(data), fp=outfile)
      # save to file:
    print(' catalog saved')

# %%
def read_image():
    print("Reading images")
    import cv2
    info = {}
    for i in range(322):
        if i<9:
            image_name='mdb00'+str(i+1)
        elif i<99:
            image_name='mdb0'+str(i+1)
        else:
            image_name = 'mdb' + str(i+1)
        # print(image_name)
        image_address= url+image_name+'.pgm'
        #print(image_address)
        #print(image_address)
        img = cv2.imread(image_address, 0)
        # print(i)
        img = cv2.resize(img, (64,64))   #resize image
        rows, cols = img.shape
        info[image_name]={}
        for angle in range(0,no_angles,2):
            M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)    #Rotate 0 degree
            img_rotated = cv2.warpAffine(img, M, (cols, rows))
            info[image_name][angle]=img_rotated
    return (info)

# %%
def read_lable():
    print("Reading labels")
    filename = url+'Info.txt'
    text_all = open(filename).read()
    #print(text_all)
    lines=text_all.split('\n')
    info={}
    for line in lines:
        words=line.split(' ')
        if len(words)>3:
            if (words[3] == 'B'):
                info[words[0]] = {}
                for angle in range(0,no_angles,2):
                    info[words[0]][angle] = 0
            if (words[3] == 'M'):
                info[words[0]] = {}
                for  angle in range(0,no_angles,2):
                    info[words[0]][angle] = 1
    return (info)

# %%
from sklearn.model_selection import train_test_split
import numpy as np
lable_info=read_lable()
image_info=read_image()
#print(image_info[1][0])
ids=lable_info.keys()   #ids = acceptable labeled ids
#print(type(ids))
del lable_info['Truth-Data:']
#print(lable_info)
#print(ids)
X=[]
Y=[]
for id in ids:
    for angle in range(0,no_angles,2):
        X.append(image_info[id][angle])
        Y.append(lable_info[id][angle])
X=np.array(X)
Y=np.array(Y)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15,shuffle=True, random_state=2021)
(a,b,c)=x_train.shape  # (60000, 28, 28)
x_train = np.reshape(x_train, (a, b, c, 1))  #1 for gray scale
(a, b, c)=x_test.shape
x_test = np.reshape(x_test, (a, b, c, 1))   #1 for gray scale
# cancer_prediction_cnn(x_train, y_train, x_test, y_test)
# Out:
# Reading labels
# Reading images

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Conv2D, MaxPool2D, Flatten
from keras import optimizers
from keras import losses
from sklearn import metrics

rows, cols,color = x_train[0].shape
model = Sequential()

model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1),input_shape=(rows,cols,1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))

model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv2D(128,(3,3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv2D(256,(3,3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv2D(128,(3,3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv2D(32,(3,3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding = 'same'))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        320
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 128)         295040
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 4, 128)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 64)          73792
# _________________________________________________________________
# activation_5 (Activation)    (None, 2, 2, 64)          0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 1, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 1, 1, 32)          18464
# _________________________________________________________________
# activation_6 (Activation)    (None, 1, 1, 32)          0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 32)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# _________________________________________________________________
# activation_7 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 775,169
# Trainable params: 775,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', patience=5,restore_best_weights=True, verbose=1)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train,validation_split=0.2, epochs=100,shuffle=True, batch_size=128,callbacks=[es])
loss_value , accuracy = model.evaluate(x_test, y_test)

print('Test_loss_value = ' +str(loss_value))
print('test_accuracy = ' + str(accuracy))

#print(model.predict(x_test))
#model.save('breast_cance_model.h5')

save_dictionary('history1.dat', history.history)
# Out:
# Epoch 1/100
# 110/110 [==============================] - 2s 19ms/step - loss: 0.7106 - accuracy: 0.5382 - val_loss: 0.6899 - val_accuracy: 0.5476
# Epoch 2/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.6895 - accuracy: 0.5450 - val_loss: 0.6890 - val_accuracy: 0.5476
# Epoch 3/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.6896 - accuracy: 0.5466 - val_loss: 0.6888 - val_accuracy: 0.5476
# Epoch 4/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.6882 - accuracy: 0.5449 - val_loss: 0.6893 - val_accuracy: 0.5476
# Epoch 5/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.6876 - accuracy: 0.5456 - val_loss: 0.6875 - val_accuracy: 0.5476
# Epoch 6/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.6835 - accuracy: 0.5423 - val_loss: 0.6800 - val_accuracy: 0.5595
# Epoch 7/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.6720 - accuracy: 0.5696 - val_loss: 0.6502 - val_accuracy: 0.5877
# Epoch 8/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.6508 - accuracy: 0.5959 - val_loss: 0.6072 - val_accuracy: 0.6320
# Epoch 9/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.6155 - accuracy: 0.6343 - val_loss: 0.5931 - val_accuracy: 0.6681
# Epoch 10/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.5717 - accuracy: 0.6806 - val_loss: 0.4792 - val_accuracy: 0.7462
# Epoch 11/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.5099 - accuracy: 0.7324 - val_loss: 0.4058 - val_accuracy: 0.8215
# Epoch 12/100
# 110/110 [==============================] - 2s 16ms/step - loss: 0.4472 - accuracy: 0.7809 - val_loss: 0.3608 - val_accuracy: 0.8457
# Epoch 13/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.3650 - accuracy: 0.8370 - val_loss: 0.2831 - val_accuracy: 0.8846
# Epoch 14/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.3139 - accuracy: 0.8627 - val_loss: 0.1808 - val_accuracy: 0.9318
# Epoch 15/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.2569 - accuracy: 0.8902 - val_loss: 0.1431 - val_accuracy: 0.9446
# Epoch 16/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.2233 - accuracy: 0.9111 - val_loss: 0.1123 - val_accuracy: 0.9614
# Epoch 17/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.1773 - accuracy: 0.9327 - val_loss: 0.0901 - val_accuracy: 0.9690
# Epoch 18/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.1463 - accuracy: 0.9449 - val_loss: 0.0537 - val_accuracy: 0.9841
# Epoch 19/100
# 110/110 [==============================] - 2s 14ms/step - loss: 0.1356 - accuracy: 0.9523 - val_loss: 0.0547 - val_accuracy: 0.9889
# Epoch 20/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.1171 - accuracy: 0.9574 - val_loss: 0.0331 - val_accuracy: 0.9912
# Epoch 21/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.0975 - accuracy: 0.9675 - val_loss: 0.0253 - val_accuracy: 0.9929
# Epoch 22/100
# 110/110 [==============================] - 2s 16ms/step - loss: 0.0855 - accuracy: 0.9702 - val_loss: 0.0310 - val_accuracy: 0.9901
# Epoch 23/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.0816 - accuracy: 0.9724 - val_loss: 0.0221 - val_accuracy: 0.9926
# Epoch 24/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.0670 - accuracy: 0.9763 - val_loss: 0.0290 - val_accuracy: 0.9909
# Epoch 25/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.0673 - accuracy: 0.9770 - val_loss: 0.0254 - val_accuracy: 0.9949
# Epoch 26/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.0639 - accuracy: 0.9800 - val_loss: 0.0119 - val_accuracy: 0.9949
# Epoch 27/100
# 110/110 [==============================] - 2s 14ms/step - loss: 0.0558 - accuracy: 0.9816 - val_loss: 0.0234 - val_accuracy: 0.9935
# Epoch 28/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.0541 - accuracy: 0.9813 - val_loss: 0.0091 - val_accuracy: 0.9977
# Epoch 29/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.0564 - accuracy: 0.9798 - val_loss: 0.0075 - val_accuracy: 0.9983
# Epoch 30/100
# 110/110 [==============================] - 2s 14ms/step - loss: 0.0436 - accuracy: 0.9855 - val_loss: 0.0103 - val_accuracy: 0.9977
# Epoch 31/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.0464 - accuracy: 0.9841 - val_loss: 0.0087 - val_accuracy: 0.9974
# Epoch 32/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.0398 - accuracy: 0.9871 - val_loss: 0.0131 - val_accuracy: 0.9957
# Epoch 33/100
# 110/110 [==============================] - 2s 14ms/step - loss: 0.0536 - accuracy: 0.9823 - val_loss: 0.0070 - val_accuracy: 0.9980
# Epoch 34/100
# 110/110 [==============================] - 2s 14ms/step - loss: 0.0328 - accuracy: 0.9890 - val_loss: 0.0134 - val_accuracy: 0.9957
# Epoch 35/100
# 110/110 [==============================] - 2s 14ms/step - loss: 0.0414 - accuracy: 0.9863 - val_loss: 0.0062 - val_accuracy: 0.9983
# Epoch 36/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.0351 - accuracy: 0.9889 - val_loss: 0.0097 - val_accuracy: 0.9974
# Epoch 37/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.0370 - accuracy: 0.9864 - val_loss: 0.0172 - val_accuracy: 0.9946
# Epoch 38/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.0318 - accuracy: 0.9888 - val_loss: 0.0054 - val_accuracy: 0.9989
# Epoch 39/100
# 110/110 [==============================] - 2s 14ms/step - loss: 0.0293 - accuracy: 0.9905 - val_loss: 0.0049 - val_accuracy: 0.9989
# Epoch 40/100
# 110/110 [==============================] - 2s 14ms/step - loss: 0.0364 - accuracy: 0.9878 - val_loss: 0.0023 - val_accuracy: 0.9994
# Epoch 41/100
# 110/110 [==============================] - 2s 14ms/step - loss: 0.0280 - accuracy: 0.9906 - val_loss: 0.0081 - val_accuracy: 0.9966
# Epoch 42/100
# 110/110 [==============================] - 2s 15ms/step - loss: 0.0276 - accuracy: 0.9914 - val_loss: 0.0057 - val_accuracy: 0.9980
# Epoch 43/100
# 110/110 [==============================] - 2s 14ms/step - loss: 0.0295 - accuracy: 0.9906 - val_loss: 0.0045 - val_accuracy: 0.9986
# Epoch 44/100
# 110/110 [==============================] - 2s 14ms/step - loss: 0.0239 - accuracy: 0.9920 - val_loss: 0.0078 - val_accuracy: 0.9980
# Epoch 45/100
# 109/110 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9900Restoring model weights from the end of the best epoch.
# 110/110 [==============================] - 2s 14ms/step - loss: 0.0321 - accuracy: 0.9901 - val_loss: 0.0034 - val_accuracy: 0.9989
# Epoch 00045: early stopping
# 98/98 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 0.9990
# Test_loss_value = 0.004225756041705608
# test_accuracy = 0.9990338087081909
# saving catalog...
#  catalog saved

# %%
#%% PLOTTING RESULTS (Train vs Validation)
import matplotlib.pyplot as plt
def Train_Val_Plot(acc,val_acc,loss,val_loss):
    
    fig, (ax1, ax2) = plt.subplots(1,2, figsize= (15,10))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    plt.show()
    

Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'])

# %%
y_pred=model.predict(x_test)
y_pred_prb=model.predict_proba(x_test)

# %%
# print(y_test)
# print(y_pred)
y_pred=[1 if x[0]>0.5 else 0 for x in y_pred]
# print(y_pred)

# %%
# def print_performance_metrics(y_test,y_pred):
#     """
#         parameters
#         ----------
#         y_test : actual label (must be in non-one hot encoded form)
#         y_pred_test : predicted labels (must be in non-one hot encoded form, common output of predict methods of classifers)

#         returns
#         -------
#         prints the accuracy, precision, recall, F1 score, ROC AUC score, Cohen Kappa Score, Matthews Corrcoef and classification report   
    
#     """
from sklearn import metrics
target=["B","M"]
print('Accuracy:', np.round(metrics.accuracy_score(y_test, y_pred),4))
print('Precision:', np.round(metrics.precision_score(y_test, y_pred, average='weighted'),4))
print('Recall:', np.round(metrics.recall_score(y_test,y_pred, average='weighted'),4))
print('F1 Score:', np.round(metrics.f1_score(y_test, y_pred, average='weighted'),4))
print('Cohen Kappa Score:', np.round(metrics.cohen_kappa_score(y_test, y_pred),4))
print('ROC AUC Score:', np.round(metrics.roc_auc_score(y_test, y_pred_prb,multi_class='ovo', average='weighted'),4))
print('\t\tClassification Report:\n', metrics.classification_report(y_test, y_pred,target_names=target))
# Out:
# Accuracy: 0.999
# Precision: 0.999
# Recall: 0.999
# F1 Score: 0.999
# Cohen Kappa Score: 0.998
# ROC AUC Score: 1.0
# 		Classification Report:
#                precision    recall  f1-score   support
#
#            B       1.00      1.00      1.00      1719
#            M       1.00      1.00      1.00      1386
#
#     accuracy                           1.00      3105
#    macro avg       1.00      1.00      1.00      3105
# weighted avg       1.00      1.00      1.00      3105
