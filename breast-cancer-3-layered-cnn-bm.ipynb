# %%
# importing all the required Libraries
from collections import Counter
import cv2
import os
import glob
import skimage
import numpy as np
import pandas as pd
import seaborn as sn
import preprocessing
from tqdm import tqdm
from PIL import Image
from os import listdir
import matplotlib.pyplot as plt
from skimage.transform import resize
from collections import Counter

sn.set()

from sklearn.svm import SVC # SVC
from sklearn import metrics
from sklearn.utils import shuffle
from xgboost import XGBClassifier # XGBClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import compute_class_weight
from sklearn.preprocessing import MinMaxScaler,LabelBinarizer
from sklearn.ensemble import AdaBoostClassifier # AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier # KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier # RandomForestClassifier
from sklearn.model_selection import train_test_split

import tensorflow 
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import AUC
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications.vgg16 import VGG16 # VGG16
from tensorflow.keras.applications.vgg19 import VGG19 # VGG19
from tensorflow.keras.applications.resnet50 import ResNet50 # ResNet50
from tensorflow.keras.applications.xception import Xception # Xception
from tensorflow.keras.applications.mobilenet import MobileNet # MobileNet
from tensorflow.keras.applications.nasnet import NASNetMobile # NASNetMobile
from tensorflow.keras.applications.densenet import DenseNet169 # DenseNet169
from tensorflow.keras.applications.densenet import DenseNet121 # DenseNet121
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2 # MobileNetV2
from tensorflow.keras.applications.inception_v3 import InceptionV3 # InceptionV3
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten, Activation, GlobalAveragePooling2D,Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
no_angles = 360
url ='/kaggle/input/mias-mammography/all-mias/'

# %%
def save_dictionary(path,data):
    print('saving catalog...')
    #open('u.item', encoding="utf-8")
    import json
    with open(path,'w') as outfile:
      json.dump(str(data), fp=outfile)
      # save to file:
    print(' catalog saved')

# %%
def read_image():
    print("Reading images")
    import cv2
    info = {}
    for i in range(322):
        if i<9:
            image_name='mdb00'+str(i+1)
        elif i<99:
            image_name='mdb0'+str(i+1)
        else:
            image_name = 'mdb' + str(i+1)
        # print(image_name)
        image_address= url+image_name+'.pgm'
        #print(image_address)
        #print(image_address)
        img = cv2.imread(image_address, 0)
        # print(i)
        img = cv2.resize(img, (64,64))   #resize image
        rows, cols = img.shape
        info[image_name]={}
        for angle in range(0,no_angles,2):
            M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)    #Rotate 0 degree
            img_rotated = cv2.warpAffine(img, M, (cols, rows))
            info[image_name][angle]=img_rotated
    return (info)

# %%
def read_lable():
    print("Reading labels")
    filename = url+'Info.txt'
    text_all = open(filename).read()
    #print(text_all)
    lines=text_all.split('\n')
    info={}
    for line in lines:
        words=line.split(' ')
        if len(words)>3:
            if (words[3] == 'B'):
                info[words[0]] = {}
                for angle in range(0,no_angles,2):
                    info[words[0]][angle] = 0
            if (words[3] == 'M'):
                info[words[0]] = {}
                for  angle in range(0,no_angles,2):
                    info[words[0]][angle] = 1
    return (info)

# %%
from sklearn.model_selection import train_test_split
import numpy as np
lable_info=read_lable()
image_info=read_image()
#print(image_info[1][0])
ids=lable_info.keys()   #ids = acceptable labeled ids
#print(type(ids))
del lable_info['Truth-Data:']
#print(lable_info)
#print(ids)
X=[]
Y=[]
for id in ids:
    for angle in range(0,no_angles,2):
        X.append(image_info[id][angle])
        Y.append(lable_info[id][angle])
X=np.array(X)
Y=np.array(Y)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15,shuffle=True, random_state=2021)
(a,b,c)=x_train.shape  # (60000, 28, 28)
x_train = np.reshape(x_train, (a, b, c, 1))  #1 for gray scale
(a, b, c)=x_test.shape
x_test = np.reshape(x_test, (a, b, c, 1))   #1 for gray scale
# cancer_prediction_cnn(x_train, y_train, x_test, y_test)
# Out:
# Reading labels
# Reading images

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Conv2D, MaxPool2D, Flatten
from keras import optimizers
from keras import losses
from sklearn import metrics

rows, cols,color = x_train[0].shape
model = Sequential()

model.add(Conv2D(32, (3, 3), padding='valid', strides=(1, 1),input_shape=(rows,cols,1)))
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1)))
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1)))
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 32)        320
# _________________________________________________________________
# activation (Activation)      (None, 62, 62, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 31, 31, 64)        18496
# _________________________________________________________________
# activation_1 (Activation)    (None, 31, 31, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 3137
# _________________________________________________________________
# activation_3 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 58,881
# Trainable params: 58,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', patience=8,restore_best_weights=True, verbose=1)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train,validation_split=0.2, epochs=100,shuffle=True, batch_size=128,callbacks=[es])
loss_value , accuracy = model.evaluate(x_test, y_test)

print('Test_loss_value = ' +str(loss_value))
print('test_accuracy = ' + str(accuracy))

#print(model.predict(x_test))
#model.save('breast_cance_model.h5')

save_dictionary('history1.dat', history.history)
# Out:
# Epoch 1/100
# 110/110 [==============================] - 2s 14ms/step - loss: 1.1583 - accuracy: 0.5186 - val_loss: 0.6901 - val_accuracy: 0.5374
# Epoch 2/100
# 110/110 [==============================] - 1s 12ms/step - loss: 0.6865 - accuracy: 0.5561 - val_loss: 0.6798 - val_accuracy: 0.5757
# Epoch 3/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.6789 - accuracy: 0.5730 - val_loss: 0.6770 - val_accuracy: 0.5885
# Epoch 4/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.6663 - accuracy: 0.5873 - val_loss: 0.6664 - val_accuracy: 0.5916
# Epoch 5/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.6500 - accuracy: 0.6078 - val_loss: 0.6513 - val_accuracy: 0.6036
# Epoch 6/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.6293 - accuracy: 0.6308 - val_loss: 0.6321 - val_accuracy: 0.6235
# Epoch 7/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.6099 - accuracy: 0.6505 - val_loss: 0.6122 - val_accuracy: 0.6542
# Epoch 8/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.5924 - accuracy: 0.6643 - val_loss: 0.5820 - val_accuracy: 0.6712
# Epoch 9/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.5613 - accuracy: 0.6930 - val_loss: 0.5552 - val_accuracy: 0.6888
# Epoch 10/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.5543 - accuracy: 0.7013 - val_loss: 0.5512 - val_accuracy: 0.7164
# Epoch 11/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.5229 - accuracy: 0.7253 - val_loss: 0.5194 - val_accuracy: 0.7224
# Epoch 12/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.4989 - accuracy: 0.7393 - val_loss: 0.5158 - val_accuracy: 0.7334
# Epoch 13/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.4774 - accuracy: 0.7578 - val_loss: 0.4789 - val_accuracy: 0.7522
# Epoch 14/100
# 110/110 [==============================] - 1s 12ms/step - loss: 0.4589 - accuracy: 0.7739 - val_loss: 0.4583 - val_accuracy: 0.7766
# Epoch 15/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.4304 - accuracy: 0.7869 - val_loss: 0.4530 - val_accuracy: 0.7835
# Epoch 16/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.4145 - accuracy: 0.8029 - val_loss: 0.4398 - val_accuracy: 0.7695
# Epoch 17/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.3911 - accuracy: 0.8126 - val_loss: 0.3945 - val_accuracy: 0.8213
# Epoch 18/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.3778 - accuracy: 0.8243 - val_loss: 0.3743 - val_accuracy: 0.8414
# Epoch 19/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.3567 - accuracy: 0.8362 - val_loss: 0.3727 - val_accuracy: 0.8457
# Epoch 20/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.3425 - accuracy: 0.8466 - val_loss: 0.3512 - val_accuracy: 0.8616
# Epoch 21/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.3270 - accuracy: 0.8526 - val_loss: 0.3608 - val_accuracy: 0.8534
# Epoch 22/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.3127 - accuracy: 0.8640 - val_loss: 0.3240 - val_accuracy: 0.8673
# Epoch 23/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.2978 - accuracy: 0.8673 - val_loss: 0.3099 - val_accuracy: 0.8710
# Epoch 24/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.2920 - accuracy: 0.8750 - val_loss: 0.2882 - val_accuracy: 0.8849
# Epoch 25/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.2699 - accuracy: 0.8855 - val_loss: 0.2623 - val_accuracy: 0.9003
# Epoch 26/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.2690 - accuracy: 0.8892 - val_loss: 0.2657 - val_accuracy: 0.8991
# Epoch 27/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.2596 - accuracy: 0.8905 - val_loss: 0.2718 - val_accuracy: 0.8960
# Epoch 28/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.2408 - accuracy: 0.9021 - val_loss: 0.2472 - val_accuracy: 0.9085
# Epoch 29/100
# 110/110 [==============================] - 1s 12ms/step - loss: 0.2339 - accuracy: 0.9033 - val_loss: 0.2295 - val_accuracy: 0.9128
# Epoch 30/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.2161 - accuracy: 0.9125 - val_loss: 0.2344 - val_accuracy: 0.9210
# Epoch 31/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.2158 - accuracy: 0.9137 - val_loss: 0.2176 - val_accuracy: 0.9253
# Epoch 32/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.2125 - accuracy: 0.9157 - val_loss: 0.2059 - val_accuracy: 0.9281
# Epoch 33/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.1937 - accuracy: 0.9246 - val_loss: 0.2038 - val_accuracy: 0.9287
# Epoch 34/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.1890 - accuracy: 0.9273 - val_loss: 0.1754 - val_accuracy: 0.9378
# Epoch 35/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.1782 - accuracy: 0.9269 - val_loss: 0.1782 - val_accuracy: 0.9352
# Epoch 36/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.1794 - accuracy: 0.9307 - val_loss: 0.1859 - val_accuracy: 0.9332
# Epoch 37/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.1722 - accuracy: 0.9321 - val_loss: 0.2047 - val_accuracy: 0.9261
# Epoch 38/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.1693 - accuracy: 0.9341 - val_loss: 0.1740 - val_accuracy: 0.9395
# Epoch 39/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.1567 - accuracy: 0.9417 - val_loss: 0.1584 - val_accuracy: 0.9491
# Epoch 40/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.1519 - accuracy: 0.9439 - val_loss: 0.1642 - val_accuracy: 0.9443
# Epoch 41/100
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1521 - accuracy: 0.9400 - val_loss: 0.1587 - val_accuracy: 0.9477
# Epoch 42/100
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1493 - accuracy: 0.9449 - val_loss: 0.1253 - val_accuracy: 0.9616
# Epoch 43/100
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1396 - accuracy: 0.9484 - val_loss: 0.1525 - val_accuracy: 0.9540
# Epoch 44/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.1320 - accuracy: 0.9503 - val_loss: 0.1326 - val_accuracy: 0.9545
# Epoch 45/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.1299 - accuracy: 0.9516 - val_loss: 0.1326 - val_accuracy: 0.9560
# Epoch 46/100
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1260 - accuracy: 0.9521 - val_loss: 0.1425 - val_accuracy: 0.9523
# Epoch 47/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.1226 - accuracy: 0.9542 - val_loss: 0.1550 - val_accuracy: 0.9514
# Epoch 48/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.1182 - accuracy: 0.9570 - val_loss: 0.1328 - val_accuracy: 0.9548
# Epoch 49/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.1226 - accuracy: 0.9557 - val_loss: 0.1203 - val_accuracy: 0.9679
# Epoch 50/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.1171 - accuracy: 0.9552 - val_loss: 0.1285 - val_accuracy: 0.9608
# Epoch 51/100
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1103 - accuracy: 0.9578 - val_loss: 0.1094 - val_accuracy: 0.9650
# Epoch 52/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.1002 - accuracy: 0.9650 - val_loss: 0.0993 - val_accuracy: 0.9668
# Epoch 53/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.1029 - accuracy: 0.9614 - val_loss: 0.1087 - val_accuracy: 0.9668
# Epoch 54/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.1010 - accuracy: 0.9625 - val_loss: 0.1164 - val_accuracy: 0.9673
# Epoch 55/100
# 110/110 [==============================] - 1s 12ms/step - loss: 0.0998 - accuracy: 0.9635 - val_loss: 0.0992 - val_accuracy: 0.9724
# Epoch 56/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.1000 - accuracy: 0.9633 - val_loss: 0.1119 - val_accuracy: 0.9665
# Epoch 57/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.1043 - accuracy: 0.9627 - val_loss: 0.0920 - val_accuracy: 0.9744
# Epoch 58/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.0958 - accuracy: 0.9666 - val_loss: 0.0961 - val_accuracy: 0.9687
# Epoch 59/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0916 - accuracy: 0.9662 - val_loss: 0.0937 - val_accuracy: 0.9713
# Epoch 60/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0842 - accuracy: 0.9680 - val_loss: 0.0710 - val_accuracy: 0.9773
# Epoch 61/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0851 - accuracy: 0.9704 - val_loss: 0.0837 - val_accuracy: 0.9722
# Epoch 62/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.0884 - accuracy: 0.9692 - val_loss: 0.0938 - val_accuracy: 0.9730
# Epoch 63/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.0963 - accuracy: 0.9648 - val_loss: 0.0907 - val_accuracy: 0.9710
# Epoch 64/100
# 110/110 [==============================] - 1s 10ms/step - loss: 0.0825 - accuracy: 0.9727 - val_loss: 0.0973 - val_accuracy: 0.9736
# Epoch 65/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0927 - accuracy: 0.9666 - val_loss: 0.0900 - val_accuracy: 0.9747
# Epoch 66/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0860 - accuracy: 0.9672 - val_loss: 0.0861 - val_accuracy: 0.9733
# Epoch 67/100
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0911 - accuracy: 0.9692 - val_loss: 0.1065 - val_accuracy: 0.9710
# Epoch 68/100
# 109/110 [============================>.] - ETA: 0s - loss: 0.0809 - accuracy: 0.9732Restoring model weights from the end of the best epoch.
# 110/110 [==============================] - 1s 11ms/step - loss: 0.0812 - accuracy: 0.9731 - val_loss: 0.0941 - val_accuracy: 0.9719
# Epoch 00068: early stopping
# 98/98 [==============================] - 0s 2ms/step - loss: 0.0693 - accuracy: 0.9794
# Test_loss_value = 0.06926368921995163
# test_accuracy = 0.9793880581855774
# saving catalog...
#  catalog saved

# %%
#%% PLOTTING RESULTS (Train vs Validation)
import matplotlib.pyplot as plt
def Train_Val_Plot(acc,val_acc,loss,val_loss):
    
    fig, (ax1, ax2) = plt.subplots(1,2, figsize= (15,10))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    plt.show()
    

Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'])

# %%
y_pred=model.predict(x_test)
y_pred_prb=model.predict_proba(x_test)

# %%
# print(y_test)
# print(y_pred)
y_pred=[1 if x[0]>0.7 else 0 for x in y_pred]
# print(y_pred)

# %%
# def print_performance_metrics(y_test,y_pred):
#     """
#         parameters
#         ----------
#         y_test : actual label (must be in non-one hot encoded form)
#         y_pred_test : predicted labels (must be in non-one hot encoded form, common output of predict methods of classifers)

#         returns
#         -------
#         prints the accuracy, precision, recall, F1 score, ROC AUC score, Cohen Kappa Score, Matthews Corrcoef and classification report   
    
#     """
from sklearn import metrics
target=["B","M"]
print('Accuracy:', np.round(metrics.accuracy_score(y_test, y_pred),4))
print('Precision:', np.round(metrics.precision_score(y_test, y_pred, average='weighted'),4))
print('Recall:', np.round(metrics.recall_score(y_test,y_pred, average='weighted'),4))
print('F1 Score:', np.round(metrics.f1_score(y_test, y_pred, average='weighted'),4))
print('ROC AUC Score:', np.round(metrics.roc_auc_score(y_test, y_pred_prb,multi_class='ovo', average='weighted'),4))
print('Cohen Kappa Score:', np.round(metrics.cohen_kappa_score(y_test, y_pred),4))
print('\t\tClassification Report:\n', metrics.classification_report(y_test, y_pred,target_names=target))
# Out:
# Accuracy: 0.971
# Precision: 0.9717
# Recall: 0.971
# F1 Score: 0.9709
# ROC AUC Score: 0.9967
# Cohen Kappa Score: 0.9411
# 		Classification Report:
#                precision    recall  f1-score   support
#
#            B       0.96      0.99      0.97      1719
#            M       0.99      0.94      0.97      1386
#
#     accuracy                           0.97      3105
#    macro avg       0.97      0.97      0.97      3105
# weighted avg       0.97      0.97      0.97      3105
